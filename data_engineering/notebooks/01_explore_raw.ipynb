# %%
import pandas as pd
import matplotlib.pyplot as pl

# %%
df = pd.read_csv("../data/raw/riyadh_resturants_raw.csv")

# %%
df.shape
# Out:
# (19361, 11)

# %%
df.columns
# Out:
# Index(['name', 'categories', 'address', 'lat', 'lng', 'price', 'likes',
#        'photos', 'tips', 'rating', 'ratingSignals'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#                            name                 categories  \
# 16750         Hardee's (هارديز)       Fast Food Restaurant
# 15803         TOM TOM (توم توم)               Burger Joint
# 11251         مطعم سفرة الطيبين          Yemeni Restaurant
# 16701  Allegro Smoothies & Cafe                       Café
# 3696         Al-Roon Restaurant  Middle Eastern Restaurant
#
#                                                  address        lat  \
# 16750  Al Thumamah (King Abdulaziz St), الرياض, الممل...  24.808137
# 15803  Abi Baker Alsadeeq Road, الرياض, المملكة العرب...  24.801067
# 11251             الرياض 12471, المملكة العربية السعودية  24.752149
# 16701  As Sahafah, Riyadh (King Abdul Aziz Branch Rd)...  24.810620
# 3696                            المملكة العربية السعودية  24.643678
#
#              lng     price  likes  photos  tips  rating  ratingSignals
# 16750  46.666183     Cheap  114.0      55    15     6.4          189.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19361 entries, 0 to 19360
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           19361 non-null  object
#  1   categories     19361 non-null  object
#  2   address        19361 non-null  object
#  3   lat            19361 non-null  float64
#  4   lng            19361 non-null  float64
#  5   price          17846 non-null  object
#  6   likes          19359 non-null  float64
#  7   photos         19361 non-null  int64
#  8   tips           19361 non-null  int64
#  9   rating         7949 non-null   float64
#  10  ratingSignals  7949 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.6+ MB

# %%
df.price.isna().sum()
# Out:
# np.int64(1515)

# %%
df.rating.isna().sum()
# Out:
# np.int64(11412)

# %%
df.rating.describe()
# Out:
# count    7949.000000
# mean        7.536231
# std         0.942969
# min         4.400000
# 25%         6.900000
# 50%         7.600000
# 75%         8.200000
# max         9.600000
# Name: rating, dtype: float64

# %%
df.price.value_counts(dropna=False)
# Out:
# price
# Cheap             13499
# Moderate           3981
# NaN                1515
# Expensive           303
# Very Expensive       63
# Name: count, dtype: int64

# %%
df.lat.describe()
# Out:
# count    19361.000000
# mean        24.722588
# std          0.082220
# min         24.469683
# 25%         24.674721
# 50%         24.737781
# 75%         24.784026
# max         24.943424
# Name: lat, dtype: float64

# %%
df.lng.describe()
# Out:
# count    19361.000000
# mean        46.697338
# std          0.074112
# min         46.272777
# 25%         46.643255
# 50%         46.693637
# 75%         46.753452
# max         46.940912
# Name: lng, dtype: float64

# %%
df[["lat", "lng"]].isna().sum()
# Out:
# lat    0
# lng    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.duplicated(subset=["name" , "lng" , "lat"]).sum()
# Out:
# np.int64(6)

# %%
df.rating.hist()
# Out:
# <Axes: >
